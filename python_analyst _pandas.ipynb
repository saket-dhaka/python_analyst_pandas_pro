# %%
import pandas as pd
import numpy as np
from datasets import load_dataset


# here i am simply importing the python libraries named - pandas , numpy and datasets.

# %%
from google.colab import files
uploaded = files.upload()

# this code is used here to import the csv file from the system so that i can import the data to. collab.
# Out:
#      <input type="file" id="files-7611e0a9-9ee9-446f-b98f-b29d85bbe091" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7611e0a9-9ee9-446f-b98f-b29d85bbe091">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.read_csv('cricket_new.csv')
# this is a basic read code in python pandas
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
df=pd.read_csv('cricket_new.csv')

#  here df contains the previous code that i created

# %%
df
# here i called out df which gave that tables that i saved in it .
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
# here i renamed the column names.
df.rename(columns={'NO':'Not_out','HS':'Highest_inn_score','BF':'balls_faced','SR':'balls_strike_rate','Mat':'Matches'})


# in this code i used the function called .rename and the used dictionary to change the names of the columns in the table.
# the dictionary provides the specific format that can be used to change the names.
# Out:
#                Player       Span  Matches  Inns  Not_out  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1    PHKD Mendis (SL)  2022-2025       14    24        3  1316
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256
# 4     GA Headley (WI)  1930-1954       22    40        4  2190
# ..                ...        ...      ...   ...      ...   ...
# 58   KD Walters (AUS)  1965-1981       74   125       14  5357
# 59  GC Smith (ICC/SA)  2002-2014      117   205       13  9265
# 60  WH Ponsford (AUS)  1924-1934       29    48        4  2122
# 61    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 62   DR Jardine (ENG)  1928-1934       22    33        6  1296
#
#    Highest_inn_score    Ave balls_faced balls_strike_rate  100  50   0    4s  \
# 0                334  99.94       9800+              58.6   29  13   7  626+
# ...

# %%
df.head()

# the head here returns the top of the numbers mostly the top 5.
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1  PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0   58.6   29  13  7  626+   6
# 1  63.79    5   5  -   137  24
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4     56   10   5  2  104+   1

# %%
# ok now lets check the null values.

df.isnull().any()

# this isnull basically returns the null values.
# Out:
# Player    False
# Span      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Ave       False
# BF        False
# SR        False
# 100       False
# 50        False
# 0         False
# 4s        False
# 6s        False
# dtype: bool

# %%
# ok so now we dont have any null values if there were any the above code would have returned the true instead of false.

# there are not any but suppose there were what would i have done

# for example runs have duplicated

df['Runs']=df['Runs'].fillna(0)

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
df.duplicated()

# this is used to see if there are any duplicated in the table that i am working on.
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
# same no duplicated we have with us
# still if we had any what would i have done.


df.drop_duplicates()

# as the name suggests the will drop all the duplicate values .
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
#This line splits the values in the ‘Span’ into two parts using the hyphen – as the seperator.

df['Span'].str.split(pat = '-')

# ok now see that format of the code .
# first i am selecting df meaning the table , then the span column and what is the span  right it's a str. so now the split will split it on the basis of the condition i am giving
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 58    [1965, 1981]
# 59    [2002, 2014]
# 60    [1924, 1934]
# 61    [1930, 1938]
# 62    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df

# you can now see as earliere the years in the span column were seperated by a ,
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
# ok now lets assign these span year to some string

df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# here i am simply creating a new column rookie year however , now see the code is almost same just at the end i have str[0].
# this means it will return the thing on the left side if it was str[1] it would have returned the thing on the right.

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year
# ...

# %%
# now the same for the final year

df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# same in this case a new column created and the other one (str[1]) is assigned to it .

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year
# ...

# %%
df.drop(['Span'] , axis=1)     # here i just dropped span.

# here i simply dropped the span column using some pre defined method .drop . and the axis 1 here means the column if it was axis 0 then it denotes to row.
# Out:
#                Player  Mat  Inns  NO  Runs    HS    Ave     BF     SR  100  \
# 0    DG Bradman (AUS)   52    80  10  6996   334  99.94  9800+   58.6   29
# 1    PHKD Mendis (SL)   14    24   3  1316  182*  62.66   2063  63.79    5
# 2      AC Voges (AUS)   20    31   7  1485  269*  61.87   2667  55.68    5
# 3     RG Pollock (SA)   23    41   4  2256   274  60.97  1707+  54.48    7
# 4     GA Headley (WI)   22    40   4  2190  270*  60.83   416+     56   10
# ..                ...  ...   ...  ..   ...   ...    ...    ...    ...  ...
# 58   KD Walters (AUS)   74   125  14  5357   250  48.26  8662+  49.16   15
# 59  GC Smith (ICC/SA)  117   205  13  9265   277  48.25  15525  59.67   27
# 60  WH Ponsford (AUS)   29    48   4  2122   266  48.22  3118+  44.77    7
# 61    SJ McCabe (AUS)   39    62   5  2748   232  48.21  3217+  60.02    6
# 62   DR Jardine (ENG)   22    33   6  1296   127  48.00  2110+  25.59    1
#
#     50   0    4s  6s Rookie_Year Final_Year
# ...

# %%
#. QUESTION -> Split up the Country from the player

df['Player'].str.split(pat='(')

# here i am simply splitting the data in column player by (,).
# Out:
# 0      [DG Bradman , AUS)]
# 1      [PHKD Mendis , SL)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 58     [KD Walters , AUS)]
# 59    [GC Smith , ICC/SA)]
# 60    [WH Ponsford , AUS)]
# 61      [SJ McCabe , AUS)]
# 62     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['Country']= df['Player'].str.split(pat='(').str[1]

# here i am creating a new column country and taking data from the player column and using str[1] assigning the thing on the right side of the data to the column country.

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year  Country
# ...

# %%
# now checking the datatypes

df.dtypes

# this .dtypes method is used to to simply return the datatype of the column.
# Out:
# Player          object
# Span            object
# Mat              int64
# Inns             int64
# NO               int64
# Runs             int64
# HS              object
# Ave            float64
# BF              object
# SR              object
# 100              int64
# 50               int64
# 0               object
# 4s              object
# 6s              object
# Rookie_Year     object
# Final_Year      object
# Country         object
# dtype: object

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year  Country
# ...

# %%
# ok now we can see that hs is returned as object . but it is not object
# ok before changing the dataype i can see that the hs column has some weird thing (*) which if  not removed will not let us change the datatype of the thing.
# ok what i will be doing here and in some ahead codes is  that taking the data - split the * and the seperated data using str[0] will
# send it to a new column.
df['Highest_inn_score']=df['HS'].str.split(pat='*')

# %%
df
# so now we can see that a new column is made for HS by the name of highest_inn_score to remove the * . but you can seee the coma in the values
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year  Country  \
# ...

# %%
# to remove that , in the new column will use str[0]
df['Highest_inn_score']=df['HS'].str.split(pat='*').str[0]

# look here what i splitted i used to make the column highest_inn _score.

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year  Country  \
# ...

# %%
#so now i will drop the HS
df.drop(['HS'],axis=1)

# now as i have taken out what i needed from the HS . so now i wll drop it using method .drop
# Out:
#                Player       Span  Mat  Inns  NO  Runs    Ave     BF     SR  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996  99.94  9800+   58.6
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  62.66   2063  63.79
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  61.87   2667  55.68
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256  60.97  1707+  54.48
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  60.83   416+     56
# ..                ...        ...  ...   ...  ..   ...    ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357  48.26  8662+  49.16
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265  48.25  15525  59.67
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122  48.22  3118+  44.77
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748  48.21  3217+  60.02
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296  48.00  2110+  25.59
#
# ...

# %%
df.dtypes
# Out:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# NO                     int64
# Runs                   int64
# HS                    object
# Ave                  float64
# BF                    object
# SR                    object
# 100                    int64
# 50                     int64
# 0                     object
# 4s                    object
# 6s                    object
# Rookie_Year           object
# Final_Year            object
# Country               object
# Highest_inn_score     object
# dtype: object

# %%
# so now lets convert the newly built columns rookie and final year to integer.
df=df.astype({'Rookie_Year':'int','Final_Year':'int'})

# this astype method is used to convert the data type of one or more column .

# %%
df.dtypes
# Out:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# NO                     int64
# Runs                   int64
# HS                    object
# Ave                  float64
# BF                    object
# SR                    object
# 100                    int64
# 50                     int64
# 0                     object
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Final_Year             int64
# Country               object
# Highest_inn_score     object
# dtype: object

# %%
# now going to do the same for balls faced

df['BF']

# ok now i can see that there is a plus sign . we. can simply remove this by using the split function
# Out:
# 0     9800+
# 1      2063
# 2      2667
# 3     1707+
# 4      416+
#       ...
# 58    8662+
# 59    15525
# 60    3118+
# 61    3217+
# 62    2110+
# Name: BF, Length: 63, dtype: object

# %%
df['BF']=df['BF'].str.split(pat='+').str[0]

# %%
df
# look now there is no + sign in Bf( balls faced )
# now i will convert this into the integer data type
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94   9800
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97   1707
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83    416
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 58   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26   8662
# 59  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 60  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22   3118
# 61    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21   3217
# 62   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00   2110
#
#        SR  100  50   0    4s  6s  Rookie_Year  Final_Year  Country  \
# ...

# %%
df['BF']=df['BF'].astype('int')

# this code is correct there is some error with the excel so i will remove the fs jackson row
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1596495352.py in <cell line: 0>()
# ----> 1 df['BF']=df['BF'].astype('int')
#       2
#       3 # this code is correct there is some error with the excel so i will remove the fs jackson row
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
# ...

# %%
# removing index 8,14,55 from axis=0
df=df.drop([8,14,55])

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1           PHKD Mendis (SL)  2022-2025   14    24   3   1316  182*  62.66
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10            GS Sobers (WI)  1954-1974   93   160  21   8032  365*  57.78
# 11            HC Brook (ENG)  2022-2025   30    50   1   2820   317  57.55
# ...

# %%
df['BF']=df['BF'].astype('int')

# %%
df.dtypes
# done first  i removed the null one than separeted + and the n changed the data type
# Out:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# NO                     int64
# Runs                   int64
# HS                    object
# Ave                  float64
# BF                     int64
# SR                    object
# 100                    int64
# 50                     int64
# 0                     object
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Final_Year             int64
# Country               object
# Highest_inn_score     object
# dtype: object

# %%
# ok now lets change the datatype of SR

df['SR']=df['SR'].astype('float')

# %%
df.dtypes
# Out:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# NO                     int64
# Runs                   int64
# HS                    object
# Ave                  float64
# BF                     int64
# SR                   float64
# 100                    int64
# 50                     int64
# 0                     object
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Final_Year             int64
# Country               object
# Highest_inn_score     object
# dtype: object

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1           PHKD Mendis (SL)  2022-2025   14    24   3   1316  182*  62.66
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10            GS Sobers (WI)  1954-1974   93   160  21   8032  365*  57.78
# 11            HC Brook (ENG)  2022-2025   30    50   1   2820   317  57.55
# ...

# %%
# question - build out career_length column
# hint convert rookie/ final year and substract

df['carrer_length']=df['Final_Year']-df['Rookie_Year']

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1           PHKD Mendis (SL)  2022-2025   14    24   3   1316  182*  62.66
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10            GS Sobers (WI)  1954-1974   93   160  21   8032  365*  57.78
# 11            HC Brook (ENG)  2022-2025   30    50   1   2820   317  57.55
# ...

# %%
# question - calculate cricketer in this data frame what is the average career length

df['carrer_length'].mean()

# this .mean method simply calculates the mean of the career_length.
# Out:
# np.float64(12.883333333333333)

# %%
# question - avg SR for cricketers who player over 10 years
df[df['carrer_length']>10]['SR'].mean()
# Out:
# np.float64(50.1370731707317)

# %%
# question - find number of cricketers who played before 1960.

df[df['Rookie_Year' ]< 1960]
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 0      DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800
# 4       GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416
# 5     H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558
# 6       E Paynter (ENG)  1931-1939   20    31   5  1540   243  59.23  1288
# 7   KF Barrington (ENG)  1955-1968   82   131  15  6806   256  58.67  4957
# 9      WR Hammond (ENG)  1927-1947   85   140  16  7249  336*  58.45  7491
# 10       GS Sobers (WI)  1954-1974   93   160  21  8032  365*  57.78  4063
# 13       JB Hobbs (ENG)  1908-1930   61   102   7  5410   211  56.94  5363
# 15       L Hutton (ENG)  1937-1955   79   138  15  6971   364  56.67  2844
# 18   GE Tyldesley (ENG)  1921-1929   14    20   2   990   122  55.00   178
# 23       AD Nourse (SA)  1935-1951   34    62   7  2960   231  53.81   108
# ...

# %%
# question - max highest inns score by country.

df.groupby('Country')['Highest_inn_score'].max()

# OK JUST  simply read the question it is pretty evident that we need 2 columns one for country second for the score .
# now i will use the .groupby method to group these 2 columns and the .max method to find the maximum highest score country.
# Out:
# Country
# AUS)        380
# ENG)        364
# ICC/IND)    319
# ICC/PAK)    329
# ICC/SA)     277
# ICC/WI)     400
# IND)        248
# NZ)         251
# PAK)        313
# SA)         278
# SL)         374
# WI)         365
# ZIM)        232
# Name: Highest_inn_score, dtype: object

# %%
# question - hundreds,fifties ,ducks (0) AVG by country.
df.groupby('Country')[['100','50']].mean()

# for taking out of 0 first convert the object data type to int and then you can take out the mean.
# Out:
#                 100         50
# Country
# AUS)      21.533333  29.066667
# ENG)      13.230769  21.692308
# ICC/IND)  29.500000  47.500000
# ICC/PAK)  25.000000  46.000000
# ICC/SA)   36.000000  48.000000
# ICC/WI)   34.000000  48.000000
# IND)      23.750000  32.000000
# NZ)       33.000000  37.000000
# PAK)      17.800000  24.200000
# SA)        9.800000  20.200000
# SL)       22.750000  34.250000
# WI)       17.166667  28.666667
# ZIM)      12.000000  27.000000

# %%
df.dtypes
# Out:
# Player                object
# Span                  object
# Mat                    int64
# Inns                   int64
# NO                     int64
# Runs                   int64
# HS                    object
# Ave                  float64
# BF                     int64
# SR                   float64
# 100                    int64
# 50                     int64
# 0                     object
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Final_Year             int64
# Country               object
# Highest_inn_score     object
# carrer_length          int64
# dtype: object
